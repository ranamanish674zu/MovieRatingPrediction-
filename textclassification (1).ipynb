# %% [markdown]
# Create a NPL pipeline to 'Clean 'Reviews Data

# %%
# ->Load input file and Read Reviews 
# ->Tokenize
# ->Remove stemming 
# ->write cleaned data to output file

# %%
sample_text="I loved this movie since I was 7 and I saw it on the opening day. It was so touching and beautiful. I strongly recommend seeing for all. It's a movie to watch with your family by far.<br/><br/> My MPAA rating: PG-13 for thematic elements, prolonged scenes of disastor, nudity/sexuality and some language."

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#init Object 
tokenizer =RegexpTokenizer(r'\w+')
en_stopwords=set(stopwords.words("english"))
ps=PorterStemmer()

# %%
from nltk.corpus.reader import Review
from IPython.core.displayhook import tokenize
def getStemmedReview(review):
  review=review.lower()
  review=review.replace("<br/><br/>"," ")
  #tokanize
  tokens=tokenizer.tokenize(review)
  new_tokens=[token for token in tokens if token not in en_stopwords]
  stemmed_tokens=[ps.stem(token) for token in new_tokens]
  cleaned_review=' '.join(stemmed_tokens)
  return cleaned_review

# from nltk.tokenize import RegexpTokenizer
# from nltk.stem import PorterStemmer
# from nltk.corpus import stopwords

# def getStemmedReview(review):
#     review = review.lower()
#     review = review.replace("<br/><br/>", " ")
#     # Tokenize
#     tokenizer = RegexpTokenizer(r'\w+')
#     tokens = tokenizer.tokenize(review)
#     # Remove stopwords
#     en_stopwords = set(stopwords.words('english'))
#     new_tokens = [token for token in tokens if token not in en_stopwords]
#     # Stem tokens
#     ps = PorterStemmer()
#     stemmed_tokens = [ps.stem(token) for token in new_tokens]
#     cleaned_review = ' '.join(stemmed_tokens)
#     return cleaned_review

# %%
sample_text = str(sample_text)
getStemmedReview(sample_text)
# Out:
# 'love movi sinc 7 saw open day touch beauti strongli recommend see movi watch famili far mpaa rate pg 13 themat element prolong scene disastor nuditi sexual languag'

# %% [markdown]
# Working with file

# %%
#write one function that accepts input file and results clean output file of movie review

# %%
import sys

def getStemmedDocument(inputFile,outputFile):
  out= open(outputFile,'w',encoding="utf8")
  with open(inputFile,encoding="utf8") as f:
    reviews=f.readlines()
  for review in reviews:
    cleaned_review=getStemmedReview(review)
    print((cleaned_review),file=out)
  out.close()
#read command line arguments
inputFile=sys.argv[1]
outputFile=sys.argv[2]
getStemmedDocument(inputFile,outputFile)
#this code has to run on system it will convert the input file into output file where will be the unique word which will be the useful for prediction
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-8c4a0a11bba1> in <cell line: 14>()
#      12 inputFile=sys.argv[1]
#      13 outputFile=sys.argv[2]
# ---> 14 getStemmedDocument(inputFile,outputFile)
#
# <ipython-input-50-8c4a0a11bba1> in getStemmedDocument(inputFile, outputFile)
#       3 def getStemmedDocument(inputFile,outputFile):
#       4   out= open(outputFile,'w',encoding="utf8")
# ----> 5   with open(inputFile,encoding="utf8") as f:
#       6     reviews=f.readlines()
#       7   for review in reviews:
#
# FileNotFoundError: [Errno 2] No such file or directory: '-f'
